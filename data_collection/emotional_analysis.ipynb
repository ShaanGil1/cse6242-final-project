# %%
import pandas as pd
import numpy as np
path = "D:/CS6242/covid19_twitter/full_data_withSentimentandStates.csv"
df = pd.read_csv(path)

# %%
df["Happy"] = None
df["Angry"] = None
df["Surprise"] = None
df["Sad"] = None
df["Fear"] = None
interval = 50000
start = 450000
end = start + interval
df = df[start:end]
print(len(df))
# Out:
# 50000

# %%
print(df)
# Out:
#         Unnamed: 0  Unnamed: 0.1             tweet_id  \
# 450000      551847        551847  1478367035839193089
# 450001      551848        551848  1478367074917494787
# 450002      551849        551849  1478367407068622850
# 450003      551850        551850  1478367469169516544
# 450004      551851        551851  1478367889455558656
# ...            ...           ...                  ...
# 499995      613346        613346  1536420961297244161
# 499996      613347        613347  1536423025028935685
# 499997      613348        613348  1536423189810651138
# 499998      613349        613349  1536424189531504646
# 499999      613350        613350  1536424818047963136
#
#                                                      text            loc_id  \
# 450000  The article shares good data but is wildly con...  76c1bb41d3de7ff1
# 450001  France detects new COVID-19 variant IHU, more ...  1c69a67ad480e1b1
# 450002  Updated visitor policy due to rising COVID num...  3df0e3eb1e91170b
# ...

# %%
#!pip install text2emotion
#!pip install emoji==1.6.3
#!pip install nltk
#nltk.download('omw-1.4')

# %%
import text2emotion as te
import nltk

# %%
text = "I hate everything"
te.get_emotion(text)
# Out:
# {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 1.0, 'Fear': 0.0}

# %%
new_col = []
count = 0
for index, row in df.iterrows():
    count+=1
    if index % 100 == 0:
        print("Progress: " + str(index/len(df)))
    if row["text"] == "error":
        new_col.append("error")
    else:
        emotion = te.get_emotion(row["text"])
        new_col.append(emotion)
# Out:
# Progress: 9.0
# Progress: 9.002
# Progress: 9.004
# Progress: 9.006
# Progress: 9.008
# Progress: 9.01
# Progress: 9.012
# Progress: 9.014
# Progress: 9.016
# Progress: 9.018
# Progress: 9.02
# Progress: 9.022
# Progress: 9.024
# Progress: 9.026
# Progress: 9.028
# Progress: 9.03
# Progress: 9.032
# Progress: 9.034
# Progress: 9.036
# Progress: 9.038
# Progress: 9.04
# Progress: 9.042
# Progress: 9.044
# Progress: 9.046
# Progress: 9.048
# Progress: 9.05
# Progress: 9.052
# Progress: 9.054
# Progress: 9.056
# Progress: 9.058
# Progress: 9.06
# Progress: 9.062
# Progress: 9.064
# Progress: 9.066
# Progress: 9.068
# Progress: 9.07
# Progress: 9.072
# Progress: 9.074
# Progress: 9.076
# Progress: 9.078
# Progress: 9.08
# Progress: 9.082
# Progress: 9.084
# Progress: 9.086
# Progress: 9.088
# Progress: 9.09
# Progress: 9.092
# Progress: 9.094
# Progress: 9.096
# Progress: 9.098
# Progress: 9.1
# Progress: 9.102
# Progress: 9.104
# Progress: 9.106
# Progress: 9.108
# Progress: 9.11
# ...

# %%
print(new_col)
for i in range(0, len(new_col)):
    df.loc[i + start, "Happy"] = new_col[i]["Happy"]
    df.loc[i + start, "Angry"] = new_col[i]["Angry"]
    df.loc[i + start, "Surprise"] = new_col[i]["Surprise"]
    df.loc[i + start, "Sad"] = new_col[i]["Sad"]
    df.loc[i + start, "Fear"] = new_col[i]["Fear"]
print(df)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#         Unnamed: 0  Unnamed: 0.1             tweet_id  \
# 450000      551847        551847  1478367035839193089
# 450001      551848        551848  1478367074917494787
# 450002      551849        551849  1478367407068622850
# 450003      551850        551850  1478367469169516544
# 450004      551851        551851  1478367889455558656
# ...            ...           ...                  ...
# 499995      613346        613346  1536420961297244161
# 499996      613347        613347  1536423025028935685
# 499997      613348        613348  1536423189810651138
# 499998      613349        613349  1536424189531504646
# ...

# %%
out = pd.DataFrame.to_csv(df, path_or_buf="D:\CS6242\covid19_twitter\\batch_" + str(start) + "-" + 
                          str(end) + ".csv")
